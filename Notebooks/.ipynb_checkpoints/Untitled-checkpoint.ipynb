# %%
import sys
import os
sys.path.insert(0, "/home/sangu/Medulu/")

# %%
from src.main import LoadImage

# %%
img = LoadImage("/home/sangu/Downloads/mni_icbm152_nlin_sym_09a_nifti/mni_icbm152_nlin_sym_09a/mni_icbm152_t1_tal_nlin_sym_09a.nii")

# %%
img.data.shape
# Out:
# (197, 233, 189)

# %%
print(img.header)
# Out:
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : np.bytes_(b'')
# db_name         : np.bytes_(b'')
# extents         : 0
# session_error   : 0
# regular         : np.bytes_(b'r')
# dim_info        : 0
# dim             : [  3 197 233 189   1   1   0   0]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : int16
# bitpix          : 16
# slice_start     : 0
# pixdim          : [1. 1. 1. 1. 0. 1. 0. 0.]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 0
# slice_code      : unknown
# xyzt_units      : 10
# cal_max         : 100.0
# cal_min         : 0.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 0
# glmin           : 0
# descrip         : np.bytes_(b'mnc2nii mni_icbm152_nlin_sym_09a/mni_icbm152_t1_tal_nlin_sym_09a.mnc mni_icbm15')
# aux_file        : np.bytes_(b'')
# qform_code      : unknown
# sform_code      : mni
# quatern_b       : 0.0
# quatern_c       : 0.0
# quatern_d       : 0.0
# qoffset_x       : 0.0
# qoffset_y       : 0.0
# qoffset_z       : 0.0
# srow_x          : [  1.   0.   0. -98.]
# srow_y          : [   0.    1.    0. -134.]
# srow_z          : [  0.   0.   1. -72.]
# intent_name     : np.bytes_(b'')
# magic           : np.bytes_(b'n+1')

# %%
sys.getsizeof(img)
# Out:
# 48

# %%
skull_strip = img.skull_strip(output_dir="/home/sangu/rought_folder")
# Out:
# Configuring model on the CPU
# Running SynthStrip model version 1
# Input image read from: /input/mni_icbm152_t1_tal_nlin_sym_09a.nii
# doneessing frame (of 1): 1
# Masked image saved to: /output/mni_icbm152_t1_tal_nlin_sym_09a_ss.nii
#
# If you use SynthStrip in your analysis, please cite:
# ----------------------------------------------------
# SynthStrip: Skull-Stripping for Any Brain Image
# A Hoopes, JS Mora, AV Dalca, B Fischl, M Hoffmann
# NeuroImage 206 (2022), 119474
# https://doi.org/10.1016/j.neuroimage.2022.119474
#
# Website: https://w3id.org/synthstrip
#
# Skull-stripped image saved at: /home/sangu/rought_folder
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~/Medulu/medulu/lib/python3.13/site-packages/nibabel/loadsave.py:101, in load(filename, **kwargs)
#     100 try:
# --> 101     stat_result = os.stat(filename)
#     102 except OSError:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/sangu/rought_foldermni_icbm152_t1_tal_nlin_sym_09a_ss.nii'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 skull_strip = img.skull_strip(output_dir="/home/sangu/rought_folder")
#
# File ~/Medulu/src/main.py:53, in LoadImage.skull_strip(self, output_dir, load_nib)
#      50 _skull_strip(self, output_dir)
#      52 if load_nib == True:
# ---> 53     return LoadImage(f'{output_dir}{self.name}_ss{get_file_ext(self.path)}')
#
# File ~/Medulu/src/main.py:17, in LoadImage.__init__(self, path)
#      15 self.path = path
#      16 self.name = os.path.basename(path).split(".")[0]
# ---> 17 self.data = self.get_data()
#      18 self.header = self.get_img().header
#
# File ~/Medulu/src/main.py:42, in LoadImage.get_data(self)
#      41 def get_data(self):
# ---> 42     return self.get_img().get_fdata()
#
# File ~/Medulu/src/main.py:37, in LoadImage.get_img(self)
#      34         img = nib.as_closest_canonical(img)
#      35         return img
# ---> 37 img = nib.load(self.path)
#      38 img = nib.as_closest_canonical(img)
#      39 return img
#
# File ~/Medulu/medulu/lib/python3.13/site-packages/nibabel/loadsave.py:103, in load(filename, **kwargs)
#     101     stat_result = os.stat(filename)
#     102 except OSError:
# --> 103     raise FileNotFoundError(f"No such file or no access: '{filename}'")
#     104 if stat_result.st_size <= 0:
#     105     raise ImageFileError(f"Empty file: '{filename}'")
#
# FileNotFoundError: No such file or no access: '/home/sangu/rought_foldermni_icbm152_t1_tal_nlin_sym_09a_ss.nii'

# %%
data = img.get_data()

# %%
co_reg = LoadImage("/home/sangu/Downloads/coreg_IXI014-HH-1236-T1_ss.nii.gz")

# %%
co_reg_data = co_reg.get_data()

# %%
co_reg_data.shape
# Out:
# (197, 233, 189)

# %%
co_reg.plot()

# %%
skull_strip = LoadImage("/home/sangu/rought_folder/mni_icbm152_t1_tal_nlin_sym_09a_ss.nii")

# %%
skull_strip.plot()

# %%
ss_data = skull_strip.get_data()
ss_data.shape
# Out:
# (197, 233, 189)

# %%
data.shape
# Out:
# (193, 229, 193)

# %%
img.plot(slice=[100, 100, 100])

# %%
img.plot()

# %%
img.plot()

# %%
import os
name = os.path.basename("/home/sangu/stipskull.nii.gz")

# %%
import os

def get_full_extension(file_path):
    extensions = []
    while True:
        file_name, file_ext = os.path.splitext(file_path)
        if file_ext:
            extensions.append(file_ext)
            file_path = file_name
        else:
            break
    return ''.join(reversed(extensions))

file_path = '/home/sangu/stipskull.hdr'
file_ext = get_full_extension(file_path)

print(file_ext)  # Output: .nii.gz
# Out:
# .hdr

# %%
img = LoadImage("/home/sangu/rought_folder/IXI039-HH-1261-T1_ss.nii.gz")

# %%
img.affine
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 img.affine
#
# AttributeError: 'LoadImage' object has no attribute 'affine'

# %%
data = img.data

# %%
data.shape
# Out:
# (150, 256, 256)

# %%
img.plot(slice=[160, 128, 75])

# %%
img.plot()

# %%
# %%time
strip_skull = img.skull_strip("/home/sangu/Medulu/Datasets/Raw/post_skull_strip")
# Out:
# Configuring model on the CPU
# Running SynthStrip model version 1
# Input image read from: /input/IXI039-HH-1261-T1.nii.gz
# doneessing frame (of 1): 1
# Masked image saved to: /output/IXI039-HH-1261-T1_ss.nii.gz
#
# If you use SynthStrip in your analysis, please cite:
# ----------------------------------------------------
# SynthStrip: Skull-Stripping for Any Brain Image
# A Hoopes, JS Mora, AV Dalca, B Fischl, M Hoffmann
# NeuroImage 206 (2022), 119474
# https://doi.org/10.1016/j.neuroimage.2022.119474
#
# Website: https://w3id.org/synthstrip
#
# Skull-stripped image saved at: /home/sangu/rought_folder
# CPU times: user 175 ms, sys: 144 ms, total: 320 ms
# Wall time: 1min 36s

# %%
strip_skull.plot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 strip_skull.plot()
#
# NameError: name 'strip_skull' is not defined

# %%
from utilities import load_files
 file_df = load_files.multiple_file_handler("/home/sangu/Downloads/MALC dataset")

# %%
from utilities.plotting import plot_files

plot_files("/home/sangu/rought_folder/trial3")

# %%
# Out:
# Ventricle mask saved as 'ventricle_mask.nii.gz'

# %%
img = LoadImage("/home/sangu/rought_folder/trial/ants_full_mask_1.nii.gz")

# %%
data = img.get_data()

# %%
img.plot()

# %%
import nibabel as nib
import numpy as np
import matplotlib.pyplot as plt

# Load MRI scan and mask
mri_path = "/home/sangu/Medulu/Datasets/Raw/post_reg_mri/coreg_IXI048-HH-1326-T1_ss.nii.gz"
mask_path_3 = "/home/sangu/rought_folder/trial/cr_ants_mask_3.nii.gz"
mask_path_1 = "/home/sangu/rought_folder/trial/cr_ants_mask_1.nii.gz"
mask_path_0 = "/home/sangu/rought_folder/trial/cr_ants_mask_0.nii.gz"

mri_img = nib.load(mri_path)
mask_img_3 = nib.load(mask_path_3)
mask_img_1 = nib.load(mask_path_1)
mask_img_0 = nib.load(mask_path_0)

mri_data = mri_img.get_fdata()
mask_data_3 = mask_img_3.get_fdata()
mask_data_1 = mask_img_1.get_fdata()
mask_data_0 = mask_img_0.get_fdata()

# Get mid-slice index
mid_slice = mri_data.shape[0] // 2

# Plot MRI with mask overlay
plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.imshow(mri_data[mid_slice, :, :], cmap="gray")
plt.title("Original MRI")
plt.axis("off")

plt.subplot(1, 2, 2)
plt.imshow(mri_data[mid_slice, :, :], cmap="gray")
plt.imshow(mask_data_3[mid_slice, :, :], cmap="plasma", alpha=0.4)  # Overlay mask in color
plt.imshow(mask_data_1[mid_slice, :, :], cmap="jet", alpha=0.4)  # Overlay mask in color
plt.imshow(mask_data_0[mid_slice, :, :], cmap="Blues", alpha=0.4)  # Overlay mask in color
plt.title("MRI with Mask Overlay")
plt.axis("off")

plt.show()

# %%
from utilities.plotting import plot_with_mask
csf = LoadImage("/home/sangu/rought_folder/trial3/n4_ant_cr_ants_mask_0.nii.gz")
gm = LoadImage("/home/sangu/rought_folder/trial3/n4_ant_cr_ants_mask_1.nii.gz")
wm = LoadImage("/home/sangu/rought_folder/trial3/n4_ant_cr_ants_mask_3.nii.gz")
orig_img = LoadImage("/home/sangu/Medulu/Datasets/Raw/post_reg_mri/coreg_IXI048-HH-1326-T1_ss.nii.gz")
plot_with_mask(orig_img, [csf, gm, wm], [120, 100, 150])

# %% [markdown]
# ## Skull strippping from folder

# %%
from utilities.skull_stripping import _skull_strip_files

# %%
_skull_strip_files("/home/sangu/Medulu/Datasets/Raw/pre_skull_strip", "/home/sangu/Medulu/Datasets/Raw/post_skull_strip2")
# Out:
# Configuring model on the CPU
# Running SynthStrip model version 1
# Input image read from: /input/IXI143-Guys-0785-T1.nii.gz
# doneessing frame (of 1): 1
# Masked image saved to: /output/IXI143-Guys-0785-T1_ss.nii.gz
#
# If you use SynthStrip in your analysis, please cite:
# ----------------------------------------------------
# SynthStrip: Skull-Stripping for Any Brain Image
# A Hoopes, JS Mora, AV Dalca, B Fischl, M Hoffmann
# NeuroImage 206 (2022), 119474
# https://doi.org/10.1016/j.neuroimage.2022.119474
#
# Website: https://w3id.org/synthstrip
#
# Skull-stripped image saved at: /home/sangu/Medulu/Datasets/Raw/post_skull_strip2
# Configuring model on the CPU
# Running SynthStrip model version 1
# Input image read from: /input/IXI138-Guys-0746-T1.nii.gz
# doneessing frame (of 1): 1
# Masked image saved to: /output/IXI138-Guys-0746-T1_ss.nii.gz
#
# If you use SynthStrip in your analysis, please cite:
# ----------------------------------------------------
# SynthStrip: Skull-Stripping for Any Brain Image
# A Hoopes, JS Mora, AV Dalca, B Fischl, M Hoffmann
# NeuroImage 206 (2022), 119474
# https://doi.org/10.1016/j.neuroimage.2022.119474
#
# Website: https://w3id.org/synthstrip
#
# Skull-stripped image saved at: /home/sangu/Medulu/Datasets/Raw/post_skull_strip2
# Configuring model on the CPU
# Running SynthStrip model version 1
# Input image read from: /input/IXI118-Guys-0764-T1.nii.gz
# doneessing frame (of 1): 1
# Masked image saved to: /output/IXI118-Guys-0764-T1_ss.nii.gz
#
# If you use SynthStrip in your analysis, please cite:
# ----------------------------------------------------
# SynthStrip: Skull-Stripping for Any Brain Image
# A Hoopes, JS Mora, AV Dalca, B Fischl, M Hoffmann
# NeuroImage 206 (2022), 119474
# https://doi.org/10.1016/j.neuroimage.2022.119474
#
# Website: https://w3id.org/synthstrip
#
# Skull-stripped image saved at: /home/sangu/Medulu/Datasets/Raw/post_skull_strip2
# Configuring model on the CPU
# Running SynthStrip model version 1
# Input image read from: /input/IXI117-Guys-0763-T1.nii.gz
# doneessing frame (of 1): 1
# Masked image saved to: /output/IXI117-Guys-0763-T1_ss.nii.gz
#
# If you use SynthStrip in your analysis, please cite:
# ----------------------------------------------------
# SynthStrip: Skull-Stripping for Any Brain Image
# A Hoopes, JS Mora, AV Dalca, B Fischl, M Hoffmann
# NeuroImage 206 (2022), 119474
# https://doi.org/10.1016/j.neuroimage.2022.119474
#
# Website: https://w3id.org/synthstrip
#
# Skull-stripped image saved at: /home/sangu/Medulu/Datasets/Raw/post_skull_strip2
# Configuring model on the CPU
# Running SynthStrip model version 1
# Input image read from: /input/IXI150-HH-1550-T1.nii.gz
# doneessing frame (of 1): 1
# Masked image saved to: /output/IXI150-HH-1550-T1_ss.nii.gz
#
# If you use SynthStrip in your analysis, please cite:
# ----------------------------------------------------
# SynthStrip: Skull-Stripping for Any Brain Image
# A Hoopes, JS Mora, AV Dalca, B Fischl, M Hoffmann
# NeuroImage 206 (2022), 119474
# https://doi.org/10.1016/j.neuroimage.2022.119474
#
# Website: https://w3id.org/synthstrip
#
# Skull-stripped image saved at: /home/sangu/Medulu/Datasets/Raw/post_skull_strip2
# Configuring model on the CPU
# Running SynthStrip model version 1
# Input image read from: /input/IXI141-Guys-0789-T1.nii.gz
# doneessing frame (of 1): 1
# Masked image saved to: /output/IXI141-Guys-0789-T1_ss.nii.gz
#
# If you use SynthStrip in your analysis, please cite:
# ----------------------------------------------------
# SynthStrip: Skull-Stripping for Any Brain Image
# A Hoopes, JS Mora, AV Dalca, B Fischl, M Hoffmann
# NeuroImage 206 (2022), 119474
# https://doi.org/10.1016/j.neuroimage.2022.119474
#
# Website: https://w3id.org/synthstrip
#
# Skull-stripped image saved at: /home/sangu/Medulu/Datasets/Raw/post_skull_strip2
# Configuring model on the CPU
# Running SynthStrip model version 1
# Input image read from: /input/IXI135-Guys-0779-T1.nii.gz
# doneessing frame (of 1): 1
# Masked image saved to: /output/IXI135-Guys-0779-T1_ss.nii.gz
#
# If you use SynthStrip in your analysis, please cite:
# ----------------------------------------------------
# SynthStrip: Skull-Stripping for Any Brain Image
# A Hoopes, JS Mora, AV Dalca, B Fischl, M Hoffmann
# NeuroImage 206 (2022), 119474
# https://doi.org/10.1016/j.neuroimage.2022.119474
#
# Website: https://w3id.org/synthstrip
#
# Skull-stripped image saved at: /home/sangu/Medulu/Datasets/Raw/post_skull_strip2
# Configuring model on the CPU
# Running SynthStrip model version 1
# Input image read from: /input/IXI130-HH-1528-T1.nii.gz
# doneessing frame (of 1): 1
# Masked image saved to: /output/IXI130-HH-1528-T1_ss.nii.gz
#
# If you use SynthStrip in your analysis, please cite:
# ----------------------------------------------------
# SynthStrip: Skull-Stripping for Any Brain Image
# A Hoopes, JS Mora, AV Dalca, B Fischl, M Hoffmann
# NeuroImage 206 (2022), 119474
# https://doi.org/10.1016/j.neuroimage.2022.119474
#
# Website: https://w3id.org/synthstrip
#
# Skull-stripped image saved at: /home/sangu/Medulu/Datasets/Raw/post_skull_strip2
# Configuring model on the CPU
# Running SynthStrip model version 1
# Input image read from: /input/IXI128-HH-1470-T1.nii.gz
# doneessing frame (of 1): 1
# Masked image saved to: /output/IXI128-HH-1470-T1_ss.nii.gz
#
# If you use SynthStrip in your analysis, please cite:
# ----------------------------------------------------
# SynthStrip: Skull-Stripping for Any Brain Image
# A Hoopes, JS Mora, AV Dalca, B Fischl, M Hoffmann
# NeuroImage 206 (2022), 119474
# https://doi.org/10.1016/j.neuroimage.2022.119474
#
# Website: https://w3id.org/synthstrip
#
# Skull-stripped image saved at: /home/sangu/Medulu/Datasets/Raw/post_skull_strip2
# Configuring model on the CPU
# Running SynthStrip model version 1
# Input image read from: /input/IXI144-Guys-0788-T1.nii.gz
# doneessing frame (of 1): 1
# Masked image saved to: /output/IXI144-Guys-0788-T1_ss.nii.gz
#
# If you use SynthStrip in your analysis, please cite:
# ----------------------------------------------------
# SynthStrip: Skull-Stripping for Any Brain Image
# A Hoopes, JS Mora, AV Dalca, B Fischl, M Hoffmann
# NeuroImage 206 (2022), 119474
# https://doi.org/10.1016/j.neuroimage.2022.119474
#
# Website: https://w3id.org/synthstrip
#
# Skull-stripped image saved at: /home/sangu/Medulu/Datasets/Raw/post_skull_strip2
# Configuring model on the CPU
# Running SynthStrip model version 1
# Input image read from: /input/IXI156-Guys-0837-T1.nii.gz
# doneessing frame (of 1): 1
# Masked image saved to: /output/IXI156-Guys-0837-T1_ss.nii.gz
#
# If you use SynthStrip in your analysis, please cite:
# ----------------------------------------------------
# SynthStrip: Skull-Stripping for Any Brain Image
# A Hoopes, JS Mora, AV Dalca, B Fischl, M Hoffmann
# NeuroImage 206 (2022), 119474
# https://doi.org/10.1016/j.neuroimage.2022.119474
#
# Website: https://w3id.org/synthstrip
#
# Skull-stripped image saved at: /home/sangu/Medulu/Datasets/Raw/post_skull_strip2
# Configuring model on the CPU
# Running SynthStrip model version 1
# Input image read from: /input/IXI116-Guys-0739-T1.nii.gz
# doneessing frame (of 1): 1
# Masked image saved to: /output/IXI116-Guys-0739-T1_ss.nii.gz
#
# If you use SynthStrip in your analysis, please cite:
# ----------------------------------------------------
# SynthStrip: Skull-Stripping for Any Brain Image
# A Hoopes, JS Mora, AV Dalca, B Fischl, M Hoffmann
# NeuroImage 206 (2022), 119474
# https://doi.org/10.1016/j.neuroimage.2022.119474
#
# Website: https://w3id.org/synthstrip
#
# Skull-stripped image saved at: /home/sangu/Medulu/Datasets/Raw/post_skull_strip2
# Configuring model on the CPU
# Running SynthStrip model version 1
# Input image read from: /input/IXI153-Guys-0782-T1.nii.gz
# doneessing frame (of 1): 1
# Masked image saved to: /output/IXI153-Guys-0782-T1_ss.nii.gz
#
# If you use SynthStrip in your analysis, please cite:
# ----------------------------------------------------
# SynthStrip: Skull-Stripping for Any Brain Image
# A Hoopes, JS Mora, AV Dalca, B Fischl, M Hoffmann
# NeuroImage 206 (2022), 119474
# https://doi.org/10.1016/j.neuroimage.2022.119474
#
# Website: https://w3id.org/synthstrip
#
# Skull-stripped image saved at: /home/sangu/Medulu/Datasets/Raw/post_skull_strip2
# Configuring model on the CPU
# Running SynthStrip model version 1
# Input image read from: /input/IXI137-HH-1472-T1.nii.gz
# doneessing frame (of 1): 1
# Masked image saved to: /output/IXI137-HH-1472-T1_ss.nii.gz
#
# If you use SynthStrip in your analysis, please cite:
# ----------------------------------------------------
# SynthStrip: Skull-Stripping for Any Brain Image
# A Hoopes, JS Mora, AV Dalca, B Fischl, M Hoffmann
# NeuroImage 206 (2022), 119474
# https://doi.org/10.1016/j.neuroimage.2022.119474
#
# Website: https://w3id.org/synthstrip
#
# Skull-stripped image saved at: /home/sangu/Medulu/Datasets/Raw/post_skull_strip2
# Configuring model on the CPU
# Running SynthStrip model version 1
# Input image read from: /input/IXI139-Guys-0815-T1.nii.gz
# doneessing frame (of 1): 1
# Masked image saved to: /output/IXI139-Guys-0815-T1_ss.nii.gz
#
# If you use SynthStrip in your analysis, please cite:
# ----------------------------------------------------
# SynthStrip: Skull-Stripping for Any Brain Image
# A Hoopes, JS Mora, AV Dalca, B Fischl, M Hoffmann
# NeuroImage 206 (2022), 119474
# https://doi.org/10.1016/j.neuroimage.2022.119474
#
# Website: https://w3id.org/synthstrip
#
# Skull-stripped image saved at: /home/sangu/Medulu/Datasets/Raw/post_skull_strip2
# Configuring model on the CPU
# Running SynthStrip model version 1
# Input image read from: /input/IXI148-HH-1453-T1.nii.gz
# doneessing frame (of 1): 1
# Masked image saved to: /output/IXI148-HH-1453-T1_ss.nii.gz
#
# If you use SynthStrip in your analysis, please cite:
# ----------------------------------------------------
# SynthStrip: Skull-Stripping for Any Brain Image
# A Hoopes, JS Mora, AV Dalca, B Fischl, M Hoffmann
# NeuroImage 206 (2022), 119474
# https://doi.org/10.1016/j.neuroimage.2022.119474
#
# Website: https://w3id.org/synthstrip
#
# Skull-stripped image saved at: /home/sangu/Medulu/Datasets/Raw/post_skull_strip2
# Configuring model on the CPU
# Running SynthStrip model version 1
# Input image read from: /input/IXI115-Guys-0738-T1.nii.gz
# doneessing frame (of 1): 1
# Masked image saved to: /output/IXI115-Guys-0738-T1_ss.nii.gz
#
# If you use SynthStrip in your analysis, please cite:
# ----------------------------------------------------
# SynthStrip: Skull-Stripping for Any Brain Image
# A Hoopes, JS Mora, AV Dalca, B Fischl, M Hoffmann
# NeuroImage 206 (2022), 119474
# https://doi.org/10.1016/j.neuroimage.2022.119474
#
# Website: https://w3id.org/synthstrip
#
# Skull-stripped image saved at: /home/sangu/Medulu/Datasets/Raw/post_skull_strip2
# Configuring model on the CPU
# Running SynthStrip model version 1
# Input image read from: /input/IXI142-Guys-0786-T1.nii.gz
# doneessing frame (of 1): 1
# Masked image saved to: /output/IXI142-Guys-0786-T1_ss.nii.gz
#
# If you use SynthStrip in your analysis, please cite:
# ----------------------------------------------------
# SynthStrip: Skull-Stripping for Any Brain Image
# A Hoopes, JS Mora, AV Dalca, B Fischl, M Hoffmann
# NeuroImage 206 (2022), 119474
# https://doi.org/10.1016/j.neuroimage.2022.119474
#
# Website: https://w3id.org/synthstrip
#
# Skull-stripped image saved at: /home/sangu/Medulu/Datasets/Raw/post_skull_strip2
# Configuring model on the CPU
# Running SynthStrip model version 1
# Input image read from: /input/IXI131-HH-1527-T1.nii.gz
# doneessing frame (of 1): 1
# Masked image saved to: /output/IXI131-HH-1527-T1_ss.nii.gz
#
# If you use SynthStrip in your analysis, please cite:
# ----------------------------------------------------
# SynthStrip: Skull-Stripping for Any Brain Image
# A Hoopes, JS Mora, AV Dalca, B Fischl, M Hoffmann
# NeuroImage 206 (2022), 119474
# https://doi.org/10.1016/j.neuroimage.2022.119474
#
# Website: https://w3id.org/synthstrip
#
# Skull-stripped image saved at: /home/sangu/Medulu/Datasets/Raw/post_skull_strip2
# Configuring model on the CPU
# Running SynthStrip model version 1
# Input image read from: /input/IXI134-Guys-0780-T1.nii.gz
# doneessing frame (of 1): 1
# Masked image saved to: /output/IXI134-Guys-0780-T1_ss.nii.gz
#
# If you use SynthStrip in your analysis, please cite:
# ----------------------------------------------------
# SynthStrip: Skull-Stripping for Any Brain Image
# A Hoopes, JS Mora, AV Dalca, B Fischl, M Hoffmann
# NeuroImage 206 (2022), 119474
# https://doi.org/10.1016/j.neuroimage.2022.119474
#
# Website: https://w3id.org/synthstrip
#
# Skull-stripped image saved at: /home/sangu/Medulu/Datasets/Raw/post_skull_strip2
# Configuring model on the CPU
# Running SynthStrip model version 1
# Input image read from: /input/IXI127-HH-1451-T1.nii.gz
# doneessing frame (of 1): 1
# Masked image saved to: /output/IXI127-HH-1451-T1_ss.nii.gz
#
# If you use SynthStrip in your analysis, please cite:
# ----------------------------------------------------
# SynthStrip: Skull-Stripping for Any Brain Image
# A Hoopes, JS Mora, AV Dalca, B Fischl, M Hoffmann
# NeuroImage 206 (2022), 119474
# https://doi.org/10.1016/j.neuroimage.2022.119474
#
# Website: https://w3id.org/synthstrip
#
# Skull-stripped image saved at: /home/sangu/Medulu/Datasets/Raw/post_skull_strip2
# Configuring model on the CPU
# Running SynthStrip model version 1
# Input image read from: /input/IXI140-Guys-0787-T1.nii.gz
# doneessing frame (of 1): 1
# Masked image saved to: /output/IXI140-Guys-0787-T1_ss.nii.gz
#
# If you use SynthStrip in your analysis, please cite:
# ----------------------------------------------------
# SynthStrip: Skull-Stripping for Any Brain Image
# A Hoopes, JS Mora, AV Dalca, B Fischl, M Hoffmann
# NeuroImage 206 (2022), 119474
# https://doi.org/10.1016/j.neuroimage.2022.119474
#
# Website: https://w3id.org/synthstrip
#
# Skull-stripped image saved at: /home/sangu/Medulu/Datasets/Raw/post_skull_strip2
# Configuring model on the CPU
# Running SynthStrip model version 1
# Input image read from: /input/IXI121-Guys-0772-T1.nii.gz
# doneessing frame (of 1): 1
# Masked image saved to: /output/IXI121-Guys-0772-T1_ss.nii.gz
#
# If you use SynthStrip in your analysis, please cite:
# ----------------------------------------------------
# SynthStrip: Skull-Stripping for Any Brain Image
# A Hoopes, JS Mora, AV Dalca, B Fischl, M Hoffmann
# NeuroImage 206 (2022), 119474
# https://doi.org/10.1016/j.neuroimage.2022.119474
#
# Website: https://w3id.org/synthstrip
#
# Skull-stripped image saved at: /home/sangu/Medulu/Datasets/Raw/post_skull_strip2
# Configuring model on the CPU
# Running SynthStrip model version 1
# Input image read from: /input/IXI132-HH-1415-T1.nii.gz
# doneessing frame (of 1): 1
# Masked image saved to: /output/IXI132-HH-1415-T1_ss.nii.gz
#
# If you use SynthStrip in your analysis, please cite:
# ----------------------------------------------------
# SynthStrip: Skull-Stripping for Any Brain Image
# A Hoopes, JS Mora, AV Dalca, B Fischl, M Hoffmann
# NeuroImage 206 (2022), 119474
# https://doi.org/10.1016/j.neuroimage.2022.119474
#
# Website: https://w3id.org/synthstrip
#
# Skull-stripped image saved at: /home/sangu/Medulu/Datasets/Raw/post_skull_strip2
# Configuring model on the CPU
# Running SynthStrip model version 1
# Input image read from: /input/IXI120-Guys-0766-T1.nii.gz
# doneessing frame (of 1): 1
# Masked image saved to: /output/IXI120-Guys-0766-T1_ss.nii.gz
#
# If you use SynthStrip in your analysis, please cite:
# ----------------------------------------------------
# SynthStrip: Skull-Stripping for Any Brain Image
# A Hoopes, JS Mora, AV Dalca, B Fischl, M Hoffmann
# NeuroImage 206 (2022), 119474
# https://doi.org/10.1016/j.neuroimage.2022.119474
#
# Website: https://w3id.org/synthstrip
#
# Skull-stripped image saved at: /home/sangu/Medulu/Datasets/Raw/post_skull_strip2
# Configuring model on the CPU
# Running SynthStrip model version 1
# Input image read from: /input/IXI145-Guys-0781-T1.nii.gz
# doneessing frame (of 1): 1
# Masked image saved to: /output/IXI145-Guys-0781-T1_ss.nii.gz
#
# If you use SynthStrip in your analysis, please cite:
# ----------------------------------------------------
# SynthStrip: Skull-Stripping for Any Brain Image
# A Hoopes, JS Mora, AV Dalca, B Fischl, M Hoffmann
# NeuroImage 206 (2022), 119474
# https://doi.org/10.1016/j.neuroimage.2022.119474
#
# Website: https://w3id.org/synthstrip
#
# Skull-stripped image saved at: /home/sangu/Medulu/Datasets/Raw/post_skull_strip2
# Configuring model on the CPU
# Running SynthStrip model version 1
# Input image read from: /input/IXI136-HH-1452-T1.nii.gz
# doneessing frame (of 1): 1
# Masked image saved to: /output/IXI136-HH-1452-T1_ss.nii.gz
#
# If you use SynthStrip in your analysis, please cite:
# ----------------------------------------------------
# SynthStrip: Skull-Stripping for Any Brain Image
# A Hoopes, JS Mora, AV Dalca, B Fischl, M Hoffmann
# NeuroImage 206 (2022), 119474
# https://doi.org/10.1016/j.neuroimage.2022.119474
#
# Website: https://w3id.org/synthstrip
#
# Skull-stripped image saved at: /home/sangu/Medulu/Datasets/Raw/post_skull_strip2
# Configuring model on the CPU
# Running SynthStrip model version 1
# Input image read from: /input/IXI129-Guys-0775-T1.nii.gz
# doneessing frame (of 1): 1
# Masked image saved to: /output/IXI129-Guys-0775-T1_ss.nii.gz
#
# If you use SynthStrip in your analysis, please cite:
# ----------------------------------------------------
# SynthStrip: Skull-Stripping for Any Brain Image
# A Hoopes, JS Mora, AV Dalca, B Fischl, M Hoffmann
# NeuroImage 206 (2022), 119474
# https://doi.org/10.1016/j.neuroimage.2022.119474
#
# Website: https://w3id.org/synthstrip
#
# Skull-stripped image saved at: /home/sangu/Medulu/Datasets/Raw/post_skull_strip2
# Configuring model on the CPU
# Running SynthStrip model version 1
# Input image read from: /input/IXI122-Guys-0773-T1.nii.gz
# doneessing frame (of 1): 1
# Masked image saved to: /output/IXI122-Guys-0773-T1_ss.nii.gz
#
# If you use SynthStrip in your analysis, please cite:
# ----------------------------------------------------
# SynthStrip: Skull-Stripping for Any Brain Image
# A Hoopes, JS Mora, AV Dalca, B Fischl, M Hoffmann
# NeuroImage 206 (2022), 119474
# https://doi.org/10.1016/j.neuroimage.2022.119474
#
# Website: https://w3id.org/synthstrip
#
# Skull-stripped image saved at: /home/sangu/Medulu/Datasets/Raw/post_skull_strip2
# Configuring model on the CPU
# Running SynthStrip model version 1
# Input image read from: /input/IXI146-HH-1389-T1.nii.gz
# doneessing frame (of 1): 1
# Masked image saved to: /output/IXI146-HH-1389-T1_ss.nii.gz
#
# If you use SynthStrip in your analysis, please cite:
# ----------------------------------------------------
# SynthStrip: Skull-Stripping for Any Brain Image
# A Hoopes, JS Mora, AV Dalca, B Fischl, M Hoffmann
# NeuroImage 206 (2022), 119474
# https://doi.org/10.1016/j.neuroimage.2022.119474
#
# Website: https://w3id.org/synthstrip
#
# Skull-stripped image saved at: /home/sangu/Medulu/Datasets/Raw/post_skull_strip2
# Configuring model on the CPU
# Running SynthStrip model version 1
# Input image read from: /input/IXI123-Guys-0774-T1.nii.gz
# doneessing frame (of 1): 1
# Masked image saved to: /output/IXI123-Guys-0774-T1_ss.nii.gz
#
# If you use SynthStrip in your analysis, please cite:
# ----------------------------------------------------
# SynthStrip: Skull-Stripping for Any Brain Image
# A Hoopes, JS Mora, AV Dalca, B Fischl, M Hoffmann
# NeuroImage 206 (2022), 119474
# https://doi.org/10.1016/j.neuroimage.2022.119474
#
# Website: https://w3id.org/synthstrip
#
# Skull-stripped image saved at: /home/sangu/Medulu/Datasets/Raw/post_skull_strip2
# Configuring model on the CPU
# Running SynthStrip model version 1
# Input image read from: /input/IXI119-Guys-0765-T1.nii.gz
# doneessing frame (of 1): 1
# Masked image saved to: /output/IXI119-Guys-0765-T1_ss.nii.gz
#
# If you use SynthStrip in your analysis, please cite:
# ----------------------------------------------------
# SynthStrip: Skull-Stripping for Any Brain Image
# A Hoopes, JS Mora, AV Dalca, B Fischl, M Hoffmann
# NeuroImage 206 (2022), 119474
# https://doi.org/10.1016/j.neuroimage.2022.119474
#
# Website: https://w3id.org/synthstrip
#
# Skull-stripped image saved at: /home/sangu/Medulu/Datasets/Raw/post_skull_strip2
# Configuring model on the CPU
# Running SynthStrip model version 1
# Input image read from: /input/IXI154-Guys-0821-T1.nii.gz
# doneessing frame (of 1): 1
# Masked image saved to: /output/IXI154-Guys-0821-T1_ss.nii.gz
#
# If you use SynthStrip in your analysis, please cite:
# ----------------------------------------------------
# SynthStrip: Skull-Stripping for Any Brain Image
# A Hoopes, JS Mora, AV Dalca, B Fischl, M Hoffmann
# NeuroImage 206 (2022), 119474
# https://doi.org/10.1016/j.neuroimage.2022.119474
#
# Website: https://w3id.org/synthstrip
#
# Skull-stripped image saved at: /home/sangu/Medulu/Datasets/Raw/post_skull_strip2
# Configuring model on the CPU
# Running SynthStrip model version 1
# Input image read from: /input/IXI151-Guys-0793-T1.nii.gz
# doneessing frame (of 1): 1
# Masked image saved to: /output/IXI151-Guys-0793-T1_ss.nii.gz
#
# If you use SynthStrip in your analysis, please cite:
# ----------------------------------------------------
# SynthStrip: Skull-Stripping for Any Brain Image
# A Hoopes, JS Mora, AV Dalca, B Fischl, M Hoffmann
# NeuroImage 206 (2022), 119474
# https://doi.org/10.1016/j.neuroimage.2022.119474
#
# Website: https://w3id.org/synthstrip
#
# Skull-stripped image saved at: /home/sangu/Medulu/Datasets/Raw/post_skull_strip2
# Configuring model on the CPU
# Running SynthStrip model version 1
# Input image read from: /input/IXI126-HH-1437-T1.nii.gz
# doneessing frame (of 1): 1
# Masked image saved to: /output/IXI126-HH-1437-T1_ss.nii.gz
#
# If you use SynthStrip in your analysis, please cite:
# ----------------------------------------------------
# SynthStrip: Skull-Stripping for Any Brain Image
# A Hoopes, JS Mora, AV Dalca, B Fischl, M Hoffmann
# NeuroImage 206 (2022), 119474
# https://doi.org/10.1016/j.neuroimage.2022.119474
#
# Website: https://w3id.org/synthstrip
#
# Skull-stripped image saved at: /home/sangu/Medulu/Datasets/Raw/post_skull_strip2

# %% [markdown]
# ### Compare Raw, Skull-stripped and Co-registered image

# %%
tem_img = LoadImage("/home/sangu/Downloads/mni_icbm152_nlin_sym_09a_nifti/mni_icbm152_nlin_sym_09a/mni_icbm152_t1_tal_nlin_sym_09a.nii")
raw_img = LoadImage("/home/sangu/Medulu/Datasets/Raw/pre_skull_strip/IXI002-Guys-0828-T1.nii.gz")
ss_img = LoadImage("/home/sangu/Medulu/Datasets/Raw/post_skull_strip/IXI002-Guys-0828-T1_ss.nii.gz")
reg_img = LoadImage("/home/sangu/Medulu/Datasets/Raw/post_reg_mri/coreg_IXI002-Guys-0828-T1_ss.nii.gz")
seg_img = LoadImage("/home/sangu/rought_folder/trial3/n4_ant_cr_ants_mask_3.nii.gz")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~/Medulu/medulu/lib/python3.13/site-packages/nibabel/loadsave.py:101, in load(filename, **kwargs)
#     100 try:
# --> 101     stat_result = os.stat(filename)
#     102 except OSError:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/sangu/Medulu/Datasets/Raw/pre_skull_strip/IXI002-Guys-0828-T1.nii.gz'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 2
#       1 tem_img = LoadImage("/home/sangu/Downloads/mni_icbm152_nlin_sym_09a_nifti/mni_icbm152_nlin_sym_09a/mni_icbm152_t1_tal_nlin_sym_09a.nii")
# ----> 2 raw_img = LoadImage("/home/sangu/Medulu/Datasets/Raw/pre_skull_strip/IXI002-Guys-0828-T1.nii.gz")
#       3 ss_img = LoadImage("/home/sangu/Medulu/Datasets/Raw/post_skull_strip/IXI002-Guys-0828-T1_ss.nii.gz")
#       4 reg_img = LoadImage("/home/sangu/Medulu/Datasets/Raw/post_reg_mri/coreg_IXI002-Guys-0828-T1_ss.nii.gz")
#
# File ~/Medulu/src/main.py:19, in LoadImage.__init__(self, path, data, affine)
#      17 self.path = path
#      18 self.name = os.path.basename(path).split(".")[0]
# ---> 19 self.data = self.get_data()
#      20 self.header = self.get_img().header
#      21 self.affine = self.get_img().affine
#
# File ~/Medulu/src/main.py:51, in LoadImage.get_data(self)
#      50 def get_data(self):
# ---> 51     return self.get_img().get_fdata()
#
# File ~/Medulu/src/main.py:46, in LoadImage.get_img(self)
#      43         img = nib.as_closest_canonical(img)
#      44         return img
# ---> 46 img = nib.load(self.path)
#      47 img = nib.as_closest_canonical(img)
#      48 return img
#
# File ~/Medulu/medulu/lib/python3.13/site-packages/nibabel/loadsave.py:103, in load(filename, **kwargs)
#     101     stat_result = os.stat(filename)
#     102 except OSError:
# --> 103     raise FileNotFoundError(f"No such file or no access: '{filename}'")
#     104 if stat_result.st_size <= 0:
#     105     raise ImageFileError(f"Empty file: '{filename}'")
#
# FileNotFoundError: No such file or no access: '/home/sangu/Medulu/Datasets/Raw/pre_skull_strip/IXI002-Guys-0828-T1.nii.gz'

# %%
print(f"Temp MRI shape {tem_img.data.shape}")
print(f"Raw MRI shape {raw_img.data.shape}")
print(f"ss MRI shape {ss_img.data.shape}")
print(f"Reg MRI shape {reg_img.data.shape}")
# Out:
# Temp MRI shape (197, 233, 189)
# Raw MRI shape (150, 256, 256)
# ss MRI shape (150, 256, 256)
# Reg MRI shape (197, 233, 189)

# %%
seg_img = LoadImage("/home/sangu/rought_folder/trial3/n4_ant_cr_ants_mask_3.nii.gz")
mri_data = seg_img.data

# %%
print(f"Seg MRI shape {seg_img.data.shape}")
# Out:
# Seg MRI shape (197, 233, 189)

# %%
import matplotlib.pyplot as plt
plt.subplot(1, 2, 1)
plt.imshow(np.rot90(mri_data[100, :, :], k=1), cmap="gray")
plt.title("Original MRI")
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(188.5), np.float64(232.5), np.float64(-0.5))
